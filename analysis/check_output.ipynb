# %%
import pandas as pd

# %%
data = pd.read_csv("../output/dataset_patients.csv.gz")
data.head(3)
# Out:
#    patient_id  start_date  index_date registered_start registered_index alive  \
# 0           1  2025-10-01  2025-11-01                T                T     T
# 1           2  2025-10-01  2025-11-01                T                T     T
# 2           3  2025-10-01  2025-11-01                T                T     T
#
#         sex  age date_of_birth      imd  ... recurrent_uti_12m  recurrent_uti  \
# 0   unknown   92    1933-10-01  Missing  ...                 F              F
# 1    female   96    1929-11-01  Missing  ...                 F              F
# 2  intersex   64    1961-06-01  Missing  ...                 F              F
#
#   include_patient_otitis_media include_patient_sinusitis  \
# 0                            F                         T
# 1                            F                         T
# 2                            F                         T
#
#   include_patient_sore_throat include_patient_insect_bites  \
# ...

# %%
df = pd.read_csv("../output/dataset_patients_2024-02-01.csv.gz")
df.head(3)
# Out:
#    patient_id  start_date  index_date registered_start registered_index alive  \
# 0           1  2024-02-01  2024-03-01                T                T     T
# 1           2  2024-02-01  2024-03-01                T                T     T
# 2           3  2024-02-01  2024-03-01                T                T     T
#
#         sex  age date_of_birth      imd  ... recurrent_uti_12m  recurrent_uti  \
# 0   unknown   90    1933-10-01  Missing  ...                 F              F
# 1    female   94    1929-11-01        3  ...                 F              F
# 2  intersex   62    1961-06-01  Missing  ...                 F              F
#
#   include_patient_otitis_media include_patient_sinusitis  \
# 0                            F                         T
# 1                            F                         T
# 2                            F                         T
#
#   include_patient_sore_throat include_patient_insect_bites  \
# ...

# %%
df2 = pd.read_csv("../output/dataset_patients_2024-03-01.csv.gz")
df2.head(3)
# Out:
#    patient_id  start_date  index_date registered_start registered_index alive  \
# 0           1  2024-03-01  2024-04-01                T                T     T
# 1           2  2024-03-01  2024-04-01                T                T     T
# 2           3  2024-03-01  2024-04-01                T                T     T
#
#         sex  age date_of_birth      imd  ... recurrent_uti_12m  recurrent_uti  \
# 0   unknown   90    1933-10-01  Missing  ...                 F              F
# 1    female   94    1929-11-01        3  ...                 F              F
# 2  intersex   62    1961-06-01  Missing  ...                 F              F
#
#   include_patient_otitis_media include_patient_sinusitis  \
# 0                            F                         T
# 1                            F                         T
# 2                            F                         T
#
#   include_patient_sore_throat include_patient_insect_bites  \
# ...

# %% [markdown]
# Question: why patient_id 9 - age 58 -> 61?
